# %%
import zipfile
import os


zip_path = "APPLE.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(".")

print(os.listdir("APPLE"))
# Out:
# ['GOOD', 'BAD', 'APPLE']

# %%
import zipfile

zip_path = '/content/APPLE.zip'
extract_path = '/content/APPLE'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("ZIP faylı açıldı.")
# Out:
# ZIP faylı açıldı.

# %%
base_dir = '/content/APPLE/APPLE'

folders = ['GOOD', 'BAD']

for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    if not os.path.exists(folder_path):
        print(f"Folder not found: {folder_path}")
        continue
    for idx, filename in enumerate(os.listdir(folder_path)):
        old_file = os.path.join(folder_path, filename)
        new_filename = f"{folder.lower()}_{idx}.jpg"
        new_file = os.path.join(folder_path, new_filename)
        os.rename(old_file, new_file)

print("Şəkil adları yeniləndi.")
# Out:
# Şəkil adları yeniləndi.

# %%
import os

base_dir = '/content/APPLE/APPLE'
folders = ['GOOD', 'BAD']

for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    if not os.path.exists(folder_path):
        print(f"Folder not found: {folder_path}")
        continue

    # Faylları sort edirik ki, indeks düz getsin
    files = sorted(os.listdir(folder_path))

    for idx, filename in enumerate(files):
        old_file = os.path.join(folder_path, filename)
        new_filename = f"{folder.lower()}_{idx}.jpg"
        new_file = os.path.join(folder_path, new_filename)
        os.rename(old_file, new_file)

print("Şəkil adları ardıcıl dəyişdirildi.")
# Out:
# Şəkil adları ardıcıl dəyişdirildi.

# %%
import os

folder_path = '/content/APPLE/APPLE/GOOD'

files = os.listdir(folder_path)
print(f"'{folder_path}' içindəki fayllar:")
for file in files:
    print(file)
# Out:
# '/content/APPLE/APPLE/GOOD' içindəki fayllar:
# good_1027.jpg
# good_1028.jpg
# good_1038.jpg
# good_14.jpg
# good_42.jpg
# good_25.jpg
# good_1014.jpg
# good_1.jpg
# good_1032.jpg
# good_67.jpg
# good_60.jpg
# good_1048.jpg
# good_1021.jpg
# good_107.jpg
# good_50.jpg
# good_146.jpg
# good_136.jpg
# good_108.jpg
# good_1015.jpg
# good_155.jpg
# good_1039.jpg
# good_1018.jpg
# good_1053.jpg
# good_1011.jpg
# good_106.jpg
# good_78.jpg
# good_86.jpg
# good_62.jpg
# good_210.jpg
# good_117.jpg
# good_12.jpg
# good_17.jpg
# good_189.jpg
# good_1008.jpg
# good_164.jpg
# good_213.jpg
# good_20.jpg
# good_1029.jpg
# good_1024.jpg
# good_126.jpg
# good_225.jpg
# good_125.jpg
# good_211.jpg
# good_157.jpg
# good_74.jpg
# good_296.jpg
# good_32.jpg
# good_188.jpg
# good_220.jpg
# good_30.jpg
# good_314.jpg
# good_64.jpg
# good_270.jpg
# good_169.jpg
# good_91.jpg
# good_9.jpg
# good_139.jpg
# good_1006.jpg
# good_79.jpg
# good_341.jpg
# good_83.jpg
# good_216.jpg
# good_320.jpg
# ...

# %%
base_dir = '/content/APPLE/APPLE'
folders = ['GOOD', 'BAD']

for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    print(f"\n{folder} qovluğundakı şəkillər:")
    if os.path.exists(folder_path):
        for file in os.listdir(folder_path):
            print(file)
    else:
        print(f"{folder} qovluğu tapılmadı.")
# Out:
# GOOD qovluğundakı şəkillər:
# good_1027.jpg
# good_1028.jpg
# good_1038.jpg
# good_14.jpg
# good_42.jpg
# good_25.jpg
# good_1014.jpg
# good_1.jpg
# good_1032.jpg
# good_67.jpg
# good_60.jpg
# good_1048.jpg
# good_1021.jpg
# good_107.jpg
# good_50.jpg
# good_146.jpg
# good_136.jpg
# good_108.jpg
# good_1015.jpg
# good_155.jpg
# good_1039.jpg
# good_1018.jpg
# good_1053.jpg
# good_1011.jpg
# good_106.jpg
# good_78.jpg
# good_86.jpg
# good_62.jpg
# good_210.jpg
# good_117.jpg
# good_12.jpg
# good_17.jpg
# good_189.jpg
# good_1008.jpg
# good_164.jpg
# good_213.jpg
# good_20.jpg
# good_1029.jpg
# good_1024.jpg
# good_126.jpg
# good_225.jpg
# good_125.jpg
# good_211.jpg
# good_157.jpg
# good_74.jpg
# good_296.jpg
# good_32.jpg
# good_188.jpg
# good_220.jpg
# good_30.jpg
# good_314.jpg
# good_64.jpg
# good_270.jpg
# good_169.jpg
# good_91.jpg
# good_9.jpg
# good_139.jpg
# good_1006.jpg
# good_79.jpg
# good_341.jpg
# good_83.jpg
# good_216.jpg
# good_320.jpg
# good_218.jpg
# good_251.jpg
# ...

# %%
print(os.path.join(folder_path, file))
# Out:
# /content/APPLE/APPLE/BAD/bad_887.jpg

# %%
import os

base_dir = '/content/APPLE/APPLE'
folders = ['GOOD', 'BAD']

for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    files = sorted(os.listdir(folder_path))

    print(f"\n{folder} qovluğundakı şəkil adları ({len(files)} şəkil):")
    for file in files:
        print(file)
# Out:
# GOOD qovluğundakı şəkil adları (730 şəkil):
# good_0.jpg
# good_1.jpg
# good_10.jpg
# good_100.jpg
# good_1000.jpg
# good_1001.jpg
# good_1002.jpg
# good_1003.jpg
# good_1004.jpg
# good_1005.jpg
# good_1006.jpg
# good_1007.jpg
# good_1008.jpg
# good_1009.jpg
# good_101.jpg
# good_1010.jpg
# good_1011.jpg
# good_1012.jpg
# good_1013.jpg
# good_1014.jpg
# good_1015.jpg
# good_1016.jpg
# good_1017.jpg
# good_1018.jpg
# good_1019.jpg
# good_102.jpg
# good_1020.jpg
# good_1021.jpg
# good_1022.jpg
# good_1023.jpg
# good_1024.jpg
# good_1025.jpg
# good_1026.jpg
# good_1027.jpg
# good_1028.jpg
# good_1029.jpg
# good_103.jpg
# good_1030.jpg
# good_1031.jpg
# good_1032.jpg
# good_1033.jpg
# good_1034.jpg
# good_1035.jpg
# good_1036.jpg
# good_1037.jpg
# good_1038.jpg
# good_1039.jpg
# good_104.jpg
# good_1040.jpg
# good_1041.jpg
# good_1042.jpg
# good_1043.jpg
# good_1044.jpg
# good_1045.jpg
# good_1046.jpg
# good_1047.jpg
# good_1048.jpg
# good_1049.jpg
# good_105.jpg
# good_1050.jpg
# ...

# %%
import os

base_dir = '/content/APPLE/APPLE'
folders = ['GOOD', 'BAD']

for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    files = sorted(os.listdir(folder_path))  # Faylları sort edirik
    for idx, filename in enumerate(files):
        old_path = os.path.join(folder_path, filename)
        new_filename = f"{folder.lower()}_{idx}.jpg"
        new_path = os.path.join(folder_path, new_filename)
        os.rename(old_path, new_path)

    print(f"{folder} qovluğunda fayllar ardıcıl adlandırıldı.")
# Out:
# GOOD qovluğunda fayllar ardıcıl adlandırıldı.
# BAD qovluğunda fayllar ardıcıl adlandırıldı.

# %%
import shutil

shutil.make_archive('/content/r_apple', 'zip', '/content/APPLE/APPLE')
# Out:
# '/content/r_apple.zip'

# %%
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

base_dir = '/content/APPLE/APPLE'

transform = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = datasets.ImageFolder(root=base_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

print(f"Datasetdə ümumilikdə {len(train_dataset)} şəkil var.")
print(f"Siniflər: {train_dataset.classes}")
# Out:
# Datasetdə ümumilikdə 1321 şəkil var.
# Siniflər: ['BAD', 'GOOD']

# %% [markdown]
# # Pipeline

# %%
from sklearn.model_selection import train_test_split
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset


data_dir = "/content/APPLE/APPLE"

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

full_dataset = datasets.ImageFolder(root=data_dir, transform=transform)


train_idx, test_idx = train_test_split(
    list(range(len(full_dataset))),
    test_size=0.2,
    stratify=full_dataset.targets,
    random_state=42
)


train_dataset = Subset(full_dataset, train_idx)
test_dataset = Subset(full_dataset, test_idx)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# CNN model

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.fc1 = nn.Linear(32 * 56 * 56, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # [batch, 16, 112, 112]
        x = self.pool(F.relu(self.conv2(x)))  # [batch, 32, 56, 56]
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# Training loop

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN().to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 5

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).float().unsqueeze(1)  # [batch,1]

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
# Out:
# Epoch 1/5, Loss: 0.7943
# Epoch 2/5, Loss: 0.4871
# Epoch 3/5, Loss: 0.4138
# Epoch 4/5, Loss: 0.3478
# Epoch 5/5, Loss: 0.2959

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        preds = torch.sigmoid(outputs).cpu().numpy() > 0.5

        all_preds.extend(preds.astype(int).flatten())
        all_labels.extend(labels.cpu().numpy())

print("Accuracy:", accuracy_score(all_labels, all_preds))
print("Precision:", precision_score(all_labels, all_preds))
print("Recall:", recall_score(all_labels, all_preds))
print("F1 Score:", f1_score(all_labels, all_preds))
# Out:
# Accuracy: 0.8301886792452831
# Precision: 0.8942307692307693
# Recall: 0.7322834645669292
# F1 Score: 0.8051948051948052

# %%
import os

base_dir = '/content/APPLE/APPLE'
classes = ['GOOD', 'BAD']

for cls in classes:
    path = os.path.join(base_dir, cls)
    print(f"{cls} qovluğu:")
    if os.path.exists(path):
        files = [f for f in os.listdir(path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        print(f"  Şəkil sayı: {len(files)}")
        print(f"  İlk 5 şəkil: {files[:5]}")
    else:
        print("  Qovluq tapılmadı!")
# Out:
# GOOD qovluğu:
#   Şəkil sayı: 633
#   İlk 5 şəkil: ['good_284.jpg', 'good_262.jpg', 'good_480.jpg', 'good_259.jpg', 'good_475.jpg']
# BAD qovluğu:
#   Şəkil sayı: 688
#   İlk 5 şəkil: ['bad_270.jpg', 'bad_450.jpg', 'bad_151.jpg', 'bad_321.jpg', 'bad_452.jpg']

# %%
from torchvision import transforms

transform_train = transforms.Compose([
    transforms.RandomResizedCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

transform_test = transforms.Compose([
    transforms.Resize(70),
    transforms.CenterCrop(64),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
from torchvision import datasets
from torch.utils.data import DataLoader, random_split

dataset = datasets.ImageFolder(base_dir, transform=transform_train)


train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

test_dataset.dataset.transform = transform_test

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)  # (batch, 16, 64, 64)
        self.pool = nn.MaxPool2d(2, 2)               # (batch, 16, 32, 32)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1) # (batch, 32, 32, 32)
        self.fc1 = nn.Linear(32 * 32 * 32, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 32 * 32)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SimpleCNN().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train_one_epoch(model, loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device).float().unsqueeze(1)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    return running_loss / len(loader.dataset)

def evaluate(model, loader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            preds = torch.sigmoid(outputs).cpu() > 0.5
            all_preds.extend(preds.squeeze().numpy())
            all_labels.extend(labels.numpy())
    return all_preds, all_labels

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

num_epochs = 5
for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

preds, labels = evaluate(model, test_loader)

acc = accuracy_score(labels, preds)
prec = precision_score(labels, preds)
rec = recall_score(labels, preds)
f1 = f1_score(labels, preds)

print(f"Test Accuracy: {acc:.4f}")
print(f"Test Precision: {prec:.4f}")
print(f"Test Recall: {rec:.4f}")
print(f"Test F1-score: {f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-64-439525477.py in <cell line: 0>()
#       3 num_epochs = 5
#       4 for epoch in range(num_epochs):
# ----> 5     train_loss = train_one_epoch(model, train_loader, criterion, optimizer)
#       6     print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")
#       7
#
# /tmp/ipython-input-63-352928914.py in train_one_epoch(model, loader, criterion, optimizer)
#      13         optimizer.zero_grad()
#      14         outputs = model(inputs)
# ---> 15         loss = criterion(outputs, labels)
#      16         loss.backward()
#      17         optimizer.step()
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# ...

# %%
print(next(iter(train_loader))[0].shape)  # Bu batch ölçüsünü göstərməlidir (32, 3, 64, 64)
# Out:
# torch.Size([32, 3, 64, 64])

# %%
def forward(self, x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(x.size(0), -1)  # batch size-ni saxla, digər ölçüləri düzləşdir
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %%
labels = labels.float().unsqueeze(1)

# %%
def train_one_epoch(model, loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device).float().unsqueeze(1)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    return running_loss / len(loader.dataset)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Transformlar
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])

# Dataset
base_dir = '/content/APPLE/APPLE'
dataset = datasets.ImageFolder(base_dir, transform=transform)

# Dataset split (80% train, 20% test)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# DataLoader-lar
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Model
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.fc1 = nn.Linear(32 * 16 * 16, 64)  # 64x64 görüntü maxpool 2 dəfə  -> 16x16
        self.fc2 = nn.Linear(64, 1)  # İkili təsnifat üçün 1 çıxış

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # (N,16,32,32)
        x = self.pool(F.relu(self.conv2(x)))  # (N,32,16,16)
        x = x.view(x.size(0), -1)             # Flatten
        x = F.relu(self.fc1(x))
        x = self.fc2(x)                       # Raw logits
        return x

model = SimpleCNN().to(device)

# Loss və optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training funksiyası
def train_one_epoch(model, dataloader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device).float().unsqueeze(1)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    return running_loss / len(dataloader.dataset)

# Training loop
num_epochs = 5
for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}")

# Test funksiyası
def evaluate(model, dataloader):
    model.eval()
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device).float().unsqueeze(1)
            outputs = model(inputs)
            probs = torch.sigmoid(outputs)
            preds = (probs > 0.5).float()
            all_labels.append(labels.cpu())
            all_preds.append(preds.cpu())
    all_labels = torch.cat(all_labels)
    all_preds = torch.cat(all_preds)
    return all_labels, all_preds

# Performans ölçmə
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

true_labels, pred_labels = evaluate(model, test_loader)
true_labels = true_labels.numpy()
pred_labels = pred_labels.numpy()

print("Accuracy:", accuracy_score(true_labels, pred_labels))
print("Precision:", precision_score(true_labels, pred_labels))
print("Recall:", recall_score(true_labels, pred_labels))
print("F1 Score:", f1_score(true_labels, pred_labels))
# Out:
# Epoch 1/5, Loss: 0.6162
# Epoch 2/5, Loss: 0.5533
# Epoch 3/5, Loss: 0.4681
# Epoch 4/5, Loss: 0.4443
# Epoch 5/5, Loss: 0.4074
# Accuracy: 0.8452830188679246
# Precision: 0.8676470588235294
# Recall: 0.8368794326241135
# F1 Score: 0.851985559566787

# %%
import os
from sklearn.model_selection import train_test_split
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# 1. Data augmentation və transformasiyalar
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

transform_test = transforms.Compose([
    transforms.Resize(72),
    transforms.CenterCrop(64),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# 2. Datasetin yeri
base_dir = '/content/APPLE/APPLE'  # öz path-inlə dəyişdir

# 3. Bütün dataset
full_dataset = datasets.ImageFolder(base_dir, transform=transform_train)

# 4. Train/Test ayırma (index-lər əsasında)
train_indices, test_indices = train_test_split(
    list(range(len(full_dataset))),
    test_size=0.2,
    stratify=[label for _, label in full_dataset.imgs]
)

train_dataset = Subset(full_dataset, train_indices)
test_dataset = Subset(full_dataset, test_indices)

# test üçün transformasiyanı yenilə (Subset ilə bunu etmək üçün sadə yol)
test_dataset.dataset.transform = transform_test

# 5. DataLoader-lar
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 6. Model (sadə CNN nümunəsi)
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(32 * 16 * 16, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))  # (batch, 16, 32, 32)
        x = self.pool(F.relu(self.conv2(x)))  # (batch, 32, 16, 16)
        x = x.view(-1, 32 * 16 * 16)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = SimpleCNN()


criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)


def train_one_epoch(model, loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    for inputs, labels in loader:
        optimizer.zero_grad()
        outputs = model(inputs).squeeze(1)
        labels = labels.float()
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    return running_loss / len(loader.dataset)


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate(model, loader):
    model.eval()
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, labels in loader:
            outputs = model(inputs).squeeze(1)
            preds = torch.sigmoid(outputs) > 0.5
            all_labels.extend(labels.tolist())
            all_preds.extend(preds.int().tolist())
    acc = accuracy_score(all_labels, all_preds)
    prec = precision_score(all_labels, all_preds)
    rec = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    return acc, prec, rec, f1


num_epochs = 20
for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer)
    acc, prec, rec, f1 = evaluate(model, test_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss:.4f}, Accuracy: {acc:.4f}, Precision: {prec:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")
# Out:
# Epoch 1/20, Loss: 0.6862, Accuracy: 0.7245, Precision: 0.7328, Recall: 0.6693, F1: 0.6996
# Epoch 2/20, Loss: 0.4768, Accuracy: 0.8113, Precision: 0.8407, Recall: 0.7480, F1: 0.7917
# Epoch 3/20, Loss: 0.4154, Accuracy: 0.8075, Precision: 0.8276, Recall: 0.7559, F1: 0.7901
# Epoch 4/20, Loss: 0.3590, Accuracy: 0.8302, Precision: 0.8796, Recall: 0.7480, F1: 0.8085
# Epoch 5/20, Loss: 0.3238, Accuracy: 0.7774, Precision: 0.9474, Recall: 0.5669, F1: 0.7094
# Epoch 6/20, Loss: 0.2971, Accuracy: 0.8038, Precision: 0.7451, Recall: 0.8976, F1: 0.8143
# Epoch 7/20, Loss: 0.2987, Accuracy: 0.8377, Precision: 0.9565, Recall: 0.6929, F1: 0.8037
# Epoch 8/20, Loss: 0.2213, Accuracy: 0.8377, Precision: 0.9375, Recall: 0.7087, F1: 0.8072
# Epoch 9/20, Loss: 0.1854, Accuracy: 0.8830, Precision: 0.9138, Recall: 0.8346, F1: 0.8724
# Epoch 10/20, Loss: 0.1482, Accuracy: 0.8868, Precision: 0.9292, Recall: 0.8268, F1: 0.8750
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate(model, dataloader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            outputs = model(inputs)
            probs = torch.sigmoid(outputs).squeeze()
            preds = (probs > 0.5).int()
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)

    return accuracy, precision, recall, f1

acc, prec, rec, f1 = evaluate(model, test_loader)
print(f"Test Accuracy: {acc:.4f}, Precision: {prec:.4f}, Recall: {rec:.4f}, F1: {f1:.4f}")
# Out:
# Test Accuracy: 0.8755, Precision: 0.9273, Recall: 0.8031, F1: 0.8608

# %%
import torch
import copy

class EarlyStopping:
    def __init__(self, patience=5, verbose=False):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.best_model_wts = None

    def __call__(self, val_loss, model):
        if self.best_loss is None or val_loss < self.best_loss:
            self.best_loss = val_loss
            self.best_model_wts = copy.deepcopy(model.state_dict())
            self.counter = 0
            if self.verbose:
                print(f"Validation loss improved to {val_loss:.4f}.")
        else:
            self.counter += 1
            if self.verbose:
                print(f"Validation loss did not improve. Counter: {self.counter}/{self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20, patience=5, device='cpu'):

    early_stopping = EarlyStopping(patience=patience, verbose=True)

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device).float().unsqueeze(1)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(train_loader.dataset)


        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                labels = labels.to(device).float().unsqueeze(1)

                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)

        val_loss = val_loss / len(val_loader.dataset)

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}")

        early_stopping(val_loss, model)

        if early_stopping.early_stop:
            print("Early stopping triggered")
            break

    model.load_state_dict(early_stopping.best_model_wts)


    torch.save(model.state_dict(), 'best_model.pth')
    print("Best model saved as best_model.pth")

    return model

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

# classes siyahısı (məsələn)
classes = ['BAD', 'GOOD']

# Məsələn, train_dataset və test_dataset PyTorch ImageFolder formatında olmalıdır
# Onlardan label-ləri çıxarırıq:

def count_labels(dataset):
    labels = [label for _, label in dataset]
    return Counter(labels)

train_counts = count_labels(train_dataset)
test_counts = count_labels(test_dataset)

train_counts_list = [train_counts[i] for i in range(len(classes))]
test_counts_list = [test_counts[i] for i in range(len(classes))]

x = np.arange(len(classes))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, train_counts_list, width, label='Train')
rects2 = ax.bar(x + width/2, test_counts_list, width, label='Test')

ax.set_ylabel('Nümunə sayı')
ax.set_title('Train və Test setdə siniflərin paylanması')
ax.set_xticks(x)
ax.set_xticklabels(classes)
ax.legend()

for rect in rects1 + rects2:
    height = rect.get_height()
    ax.annotate(f'{height}',
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0,3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.show()

# %%
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        probs = torch.sigmoid(outputs).squeeze()
        preds = (probs > 0.5).long()

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(all_labels, all_preds)
print(f"Test dəqiqliyi: {accuracy:.4f}")
# Out:
# Test dəqiqliyi: 0.8755

# %%
for i in range(5):
    print(f"Nümunə {i+1}: Proqnoz = {all_preds[i]}, Əsl = {all_labels[i]}")
# Out:
# Nümunə 1: Proqnoz = 1, Əsl = 1
# Nümunə 2: Proqnoz = 0, Əsl = 0
# Nümunə 3: Proqnoz = 0, Əsl = 0
# Nümunə 4: Proqnoz = 0, Əsl = 0
# Nümunə 5: Proqnoz = 1, Əsl = 1

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['BAD', 'GOOD'])
disp.plot()
plt.show()
